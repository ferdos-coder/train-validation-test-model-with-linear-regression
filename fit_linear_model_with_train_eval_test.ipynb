# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"E:\machine learning excercise\pista\جلسه 24\Advertising.csv")

# %% [markdown]
# #روش کلاسیک train/test split

# %% [markdown]
# Train | Test Split Procedure
#
# 1. Clean and Adjust data as necessary for X and y
# 2. Split data in Train | Test for both X and y
# 3. Fit/Train scalar on Training X data
# 4. Scale X Test Data
# 5. Create Model
# 6. Fit/Train Model on X train data
# 7. Evaluate Model on X Test Data (by creating prediction and comparing to y_test)
# 8. Adjust Parameters as necessary and repeat steps 5 and 6

# %%
X = df.drop('sales',axis=1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
scalar.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scalar.transform(X_train)

# %%
X_test = scalar.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 7.341775789034128

# %%
model2 = Ridge(alpha=1)

# %%
model2.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred2 = model2.predict(X_test)

# %%
mean_squared_error(y_test,y_pred2)
# Out:
# 2.3190215794287514

# %% [markdown]
# #روش train/validation/test split

# %%
X = df.drop('sales',axis=1)
y = df['sales']
from sklearn.model_selection import train_test_split

# %%
X_train, X_other, y_train, y_other = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
X_eval, X_test, y_eval, y_test = train_test_split(X_other,y_other,test_size=0.5,random_state=101)

# %%
len(X_train)
# Out:
# 140

# %%
len(X_eval)
# Out:
# 30

# %%
len(X_test)
# Out:
# 30

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
scalar.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scalar.transform(X_train)
X_eval = scalar.transform(X_eval)
X_test = scalar.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_eval_pred = model.predict(X_eval)

# %%
mean_squared_error(y_eval,y_eval_pred)
# Out:
# 7.320101458823869

# %%
model2 = Ridge(alpha=1)

# %%
model2.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_eval_pred2 = model2.predict(X_eval)

# %%
mean_squared_error(y_eval,y_eval_pred2)
# Out:
# 2.3837830750569853

# %% [markdown]
# #تست نهایی مدل

# %%
y_final = model2.predict(X_test)

# %%
mean_squared_error(y_test,y_final)
# Out:
# 2.254260083800517

# %% [markdown]
# K-fold cross validation

# %%
X = df.drop('sales',axis=1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
scalar.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scalar.transform(X_train)

# %%
X_test = scalar.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
scores
# Out:
# array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#         -8.38562723])

# %%
abs(scores.mean())
# Out:
# np.float64(8.215396464543607)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=1)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
abs(scores.mean())
# Out:
# np.float64(3.344839296530695)

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final2 = model.predict(X_test)

# %%
mean_squared_error(y_test,y_final2)
# Out:
# 2.3190215794287514

# %%
from sklearn.model_selection import cross_validate

# %%
model3 = Ridge(alpha=100)

# %%
scores1 = cross_validate(model3,X_train,y_train,scoring=['neg_mean_squared_error','neg_mean_absolute_error'],cv=15)

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#           0
# 0 -3.155132
# 1 -1.580870
# 2 -5.404556
# 3 -2.216545
# 4 -4.367094

# %%
scores.mean()
# Out:
# 0   -3.344839
# dtype: float64

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final = model.predict(X_test)

# %%
mean_squared_error(y_test,y_final)
# Out:
# 2.3190215794287514
